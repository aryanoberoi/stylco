# %%
from openai import OpenAI
client = OpenAI()
completion = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "user", "content": "give only json output of the following old woman plus sized who likes traditional dressing up and needs comfortable yet stylish outfits to wear json output format should be {'top', 'lower', 'footwear', 'accessories'}. nothing else only json no other text"},
    ],
response_format={"type": "json_object"}
)
json_string=str(completion.choices[0].message.content)
json_string
# Out:
# '{\n    "top": "Flowy tunic blouse with ethnic prints",\n    "lower": "Elastic-waist A-line maxi skirt",\n    "footwear": "Cushioned leather loafers",\n    "accessories": "Handcrafted beaded necklace"\n}'

# %%
import json
# Parse the JSON string into a dictionary
data = json.loads(json_string)

# Extract fields into variables as strings
top= data["top"]  # Extract the "setup" field
lower = data["lower"]  # Extract the "punchline" field
fw = data["footwear"] 
acc = data["accessories"]  # Extract the "punchline" field

# %%
import requests

url = "https://asos10.p.rapidapi.com/api/v1/getProductListBySearchTerm"

querystring = {"searchTerm":str(top),"currency":"USD","country":"US","store":"US","languageShort":"en","sizeSchema":"US","limit":"50","offset":"0","sort":"recommended"}

headers = {
	"x-rapidapi-key": "fc0c68290dmsh3cf8773797e5583p166416jsn473dab7edd58",
	"x-rapidapi-host": "asos10.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': True, 'timestamp': 1732755360305, 'data': {'searchTerm': 'Flowy tunic blouse with ethnic prints', 'categoryName': None, 'itemCount': 131, 'redirectUrl': '', 'products': [{'id': 206717064, 'name': 'Miss Selfridge collared tie front blouse in animal print', 'price': {'current': {'value': 23.84, 'text': '$23.84'}, 'previous': {'value': 52.99, 'text': '$52.99'}, 'rrp': {'value': None, 'text': ''}, 'lowestPriceInLast30Days': {'value': 40, 'text': '$40.00'}, 'isMarkedDown': True, 'isOutletPrice': False, 'currency': 'USD'}, 'colour': 'Animal Print', 'colourWayId': 206717065, 'brandName': 'Miss Selfridge', 'hasVariantColours': False, 'hasMultiplePrices': False, 'groupId': None, 'productCode': 136067167, 'productType': 'Product', 'url': 'miss-selfridge/miss-selfridge-collared-tie-front-blouse-in-animal-print/prd/206717064#colourWayId-206717065', 'imageUrl': 'images.asos-media.com/products/miss-selfridge-collared-tie-front-blouse-in-animal-print/206717064-1-animalprint', 'additional
# ...
